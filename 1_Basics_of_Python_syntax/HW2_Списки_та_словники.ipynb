# %% [markdown]
# **1. Списки - базові операції**
#
# Створіть список температур за тиждень (у градусах Цельсія) з назвою
# `temperatures` і значеннями [22, 25, 19, 23, 26, 20, 21, 22].
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть перший елемент
# - Виведіть останній елемент
# - Додайте температуру 24
# - Видаліть температуру 19
# - Виведіть довжину списку
# - Обчисліть суму всіх температур
# - Знайдіть максимальну температуру

# %%
temperatures = [22, 25, 19, 23, 26, 20, 21, 22]

print('Наш початковий список:', temperatures)
print('Перший елемент:', temperatures[0])
print('Останній елемент:', temperatures[-1])
temperatures.append(24)
print('Додали в список температуру 24:', temperatures)
temperatures.remove(19) 
print('Видалили зі списку температуру 19:', temperatures)
print('Довжина списку:', len(temperatures))
print('Сума всіх температур:', sum(temperatures))
print('Максимальна температура:', max(temperatures))
# Out:
# Наш початковий список: [22, 25, 19, 23, 26, 20, 21, 22]
# Перший елемент: 22
# Останній елемент: 22
# Додали в список температуру 24: [22, 25, 19, 23, 26, 20, 21, 22, 24]
# Видалили зі списку температуру 19: [22, 25, 23, 26, 20, 21, 22, 24]
# Довжина списку: 8
# Сума всіх температур: 183
# Максимальна температура: 26

# %% [markdown]
# **2. Словники - базові операції**
#
# Створіть словник про себе, який містить ключі `name`, `age`, `city` і значення, які відповідають вашему імені, віку і місту (можна вставити будь-які значення, не обовʼязково свої).
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть значення ключа "name"
# - Змініть значення ключа "age" на 21
# - Додайте новий ключ "hobby" зі значенням "programming"
# - Виведіть всі ключі
# - Виведіть всі значення

# %%
person = {
    'name' : 'Daria',
    'age' : 32,
    'city' : 'Kyiv'
}

print('Імʼя:', person['name']) 
person['age'] = 21
print('Нове значення \'age\':', person['age']) 
person['hobby'] = 'programming'
print('Додали новий ключ \'hobby\' зі значенням \'programming\':', person)
print('Всі ключі:', person.keys()) 
print('Всі ключі списком:', list(person.keys())) 
print('Всі значення:', person.values()) 
print('Всі значення списком:', list(person.values()))
# Out:
# Імʼя: Daria
# Нове значення 'age': 21
# Додали новий ключ 'hobby' зі значенням 'programming': {'name': 'Daria', 'age': 21, 'city': 'Kyiv', 'hobby': 'programming'}
# Всі ключі: dict_keys(['name', 'age', 'city', 'hobby'])
# Всі ключі списком: ['name', 'age', 'city', 'hobby']
# Всі значення: dict_values(['Daria', 21, 'Kyiv', 'programming'])
# Всі значення списком: ['Daria', 21, 'Kyiv', 'programming']
